# %% [markdown]
# # Import layers

# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from pathlib import Path

# %%
p = Path()
LOCAL_PATH = str(p.cwd().parent.parent)
LOCAL_PATH
# Out:
# '/home/gheorghe/Desktop/s_AI/shared_deep_learning/tensorflow/optimizers'

# %%
# adding local_folder to the system path
sys.path.append(LOCAL_PATH)

# %%
from learning_rate_schedule.code.custom_schedule import *
# Out:
# 2025-08-11 17:47:49.770158: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-08-11 17:47:49.777707: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1754923669.786038   48756 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1754923669.788530   48756 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %% [markdown]
# # Make schedule

# %%
learning_rate = CustomSchedule(d_model=96*3, warmup_steps=4000)

plt.plot(learning_rate(tf.range(20000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# I0000 00:00:1754923673.290320   48756 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 21596 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4090, pci bus id: 0000:01:00.0, compute capability: 8.9
# Text(0.5, 0, 'Train Step')

# %%
learning_rate = CustomSchedule(d_model=100, warmup_steps=16000)
plt.plot(learning_rate(tf.range(20000, dtype=tf.float32)))
plt.ylabel("Learning Rate")
plt.xlabel("Train Step")
# Out:
# Text(0.5, 0, 'Train Step')
